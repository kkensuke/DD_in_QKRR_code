# %%
import numpy as np
from QKRR import SyntheticQuantumDataset, NumericalTestRisk, TheoreticalTestRisk

# %% [markdown]
# ## Set common parameters across numerical and theoretical plots

# %%
N_QUBITS = 3
LAMBDA_LIST = [1e-10, 1e-8, 1e-6, 1e-4, 1e-2]
NOISE_SIGMA = 0.3
REPS = 100
TPA_bool = True
TEACHER_SEED = 31
DATA_SEED = TEACHER_SEED + 100
ESTIMATION_SEED = TEACHER_SEED + 200

# %%
numerical_tester = NumericalTestRisk(N_QUBITS=N_QUBITS, LAMBDA_LIST=LAMBDA_LIST, REPS=REPS, TPA=TPA_bool)

TRAIN_POOL_SIZE = REPS * numerical_tester.max_train
print(TRAIN_POOL_SIZE)
# Out:
# Training sample sizes: [17, 20, 24, 27, 30, 34]
# 3400

# %%
# The teacher, data sample, and estimation sample use independent RNG streams.
teacher_generator = SyntheticQuantumDataset(
    N_QUBITS=N_QUBITS, noise_sigma=NOISE_SIGMA, seed=TEACHER_SEED, TPA=TPA_bool
)
shared_true_params = teacher_generator.generate_true_params()

synthetic_dataset = SyntheticQuantumDataset(
    N_QUBITS=N_QUBITS,
    train_size=TRAIN_POOL_SIZE,
    test_size=1000,
    noise_sigma=NOISE_SIGMA,
    seed=DATA_SEED,
    TPA=TPA_bool,
)
X_train, y_train, X_test, y_test = (
    synthetic_dataset.generate_dataset(true_params=shared_true_params)
)

# %% [markdown]
# ## Numerical Test Risk

# %%
# numerical_tester.numerical_test_risk_lambda_optimized(X_train, y_train, X_test, y_test)
# numerical_tester.save_results("results/QKRR_synthetic_3qubits_TPA_numerical_revised.pkl")

# %%
numerical_tester = NumericalTestRisk(N_QUBITS=N_QUBITS, LAMBDA_LIST=LAMBDA_LIST, TPA=TPA_bool)
numerical_tester.load_results("results/QKRR_synthetic_3qubits_TPA_numerical_revised.pkl")
# Out:
# Training sample sizes: [17, 20, 24, 27, 30, 34]

# %%
numerical_tester.plot_mse_test()

# %% [markdown]
# ## Theoretical Test Risk

# %%
# N_EST = 3000
# estimation_dataset = SyntheticQuantumDataset(N_QUBITS=N_QUBITS, noise_sigma=NOISE_SIGMA, seed=ESTIMATION_SEED, TPA=TPA_bool)
# X_est, _, f_est = estimation_dataset.generate_samples(N_EST, shared_true_params)

# theoretical_tester = TheoreticalTestRisk(N_QUBITS=N_QUBITS, LAMBDA_LIST=LAMBDA_LIST, noise_sigma=NOISE_SIGMA, TPA=TPA_bool)
# # Use the noise-free teacher values to estimate beta_*.
# theoretical_tester.theoretical_test_risk_lambda(X_est, f_est)
# theoretical_tester.save_results("results/QKRR_synthetic_3qubits_TPA_theoretical_revised.pkl")

# %%
theoretical_tester = TheoreticalTestRisk(N_QUBITS=N_QUBITS, LAMBDA_LIST=LAMBDA_LIST, noise_sigma=NOISE_SIGMA, TPA=TPA_bool)
theoretical_tester.load_results("results/QKRR_synthetic_3qubits_TPA_theoretical_revised.pkl")

# %%
theoretical_tester.plot_theoretical_test()

# %%
# theoretical_tester.plot_effective_DOF()

# %%
import numpy as np
import matplotlib.pyplot as plt

colors = plt.cm.viridis(np.linspace(0, 0.8, len(LAMBDA_LIST)))
numerical_ratio_list = 3 ** N_QUBITS / np.array(numerical_tester.n_train_list)
theoretical_ratio_list = 3 ** N_QUBITS / np.array(theoretical_tester.n_train_list)

for i, lam in enumerate(LAMBDA_LIST):
    plt.semilogy(
        numerical_ratio_list,
        numerical_tester.mse_test_all_mean[lam],
        marker='o',
        alpha=0.8,
        linestyle='none',
        color=colors[i]
    )

for i, lam in enumerate(LAMBDA_LIST):
    plt.semilogy(
        theoretical_ratio_list,
        theoretical_tester.R_theoretical_list[i],
        label=f'λ = {lam:.0e}',
        color=colors[i]
    )

plt.plot([], [], '-', color='lightgray', label='Theory')
plt.plot([], [], 'o', color='lightgray', label='Numerics')

plt.xlabel(f'$\gamma = 3^{N_QUBITS}/N_{{tr}}$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(5e-2, 1e4)
plt.title(f'Test Risk (Synthetic, {N_QUBITS} qubits)', fontsize=20)
plt.legend(title='Regularization λ', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'results/QKRR_synthetic_{N_QUBITS}qubits_TPA.pdf')
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\g'
# <>:29: SyntaxWarning: invalid escape sequence '\g'
# /var/folders/9k/y9ch3jl55qd4kn1j6b53yyjw0000gn/T/ipykernel_2079/1314425605.py:29: SyntaxWarning: invalid escape sequence '\g'
#   plt.xlabel(f'$\gamma = 3^{N_QUBITS}/N_{{tr}}$', fontsize=18)
